# %%
ice_cream_rating = input("Введите значение для мороженого: ")
# Out:
# Введите значение для мороженого:  7

# %%
sleep_rating = input("Введите значение для сна: ")
# Out:
# Введите значение для сна:  10

# %%
happiness_rating = ((int(ice_cream_rating) + int(sleep_rating)) / 2)
print(happiness_rating)
# Out:
# 8.5

# %%
first_name = "Maxim "
last_name = "Samoylenko"
my_name = (first_name + last_name)
print(my_name)
# Out:
# Maxim Samoylenko

# %%
type(ice_cream_rating)
# Out:
# str

# %%
type(sleep_rating)
# Out:
# str

# %%
type(happiness_rating)
# Out:
# float
